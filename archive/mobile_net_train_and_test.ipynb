# %%
import os
import sys
import gc
import json
import random
#fpath = os.path.join(os.getcwd(), 'mobilestereonet', 'datasets')
#sys.path.append(fpath)
from argoverse.data_loading.stereo_dataloader import ArgoverseStereoDataLoader
from argoverse.evaluation.stereo.utils import compute_disparity_error_image
import matplotlib.pyplot as plt
import numpy as np
fpath = os.path.abspath(os.path.join(os.getcwd(), '..'))
fpath_mobilenet = os.path.join(fpath, 'mobilestereonet')
#fpath_utils = os.path.join(fpath, 'utils')
sys.path.append(fpath)
sys.path.append(fpath_mobilenet)
#sys.path.append(fpath_utils)
print(fpath)
from mobilestereonet.models import __models__, model_loss
from mobilestereonet.utils import *
from mobilestereonet.utils.KittiColormap import *
from IPython.display import clear_output

import torch
import torch.optim as optim
import time
from tensorboardX import SummaryWriter
from torch.utils.data import DataLoader

from math import floor
from torch.utils.data import Dataset
from argoverse.utils.camera_stats import RECTIFIED_STEREO_CAMERA_LIST
import torchvision.transforms as transforms

from argoverse.evaluation.stereo.eval import StereoEvaluator
from argoverse.utils.calibration import get_calibration_config
from argoverse.utils.camera_stats import RECTIFIED_STEREO_CAMERA_LIST

from pathlib import Path
from argoverse.evaluation.stereo.utils import compute_disparity_error_image

#import dataset
# Out:
# /home/ubutubiggerbetter/Desktop/249_project/testing_build

# %%
#BUild dataset class for the translation between mobilenet and argoverse data
STEREO_FRONT_LEFT_RECT = RECTIFIED_STEREO_CAMERA_LIST[0]
STEREO_FRONT_RIGHT_RECT = RECTIFIED_STEREO_CAMERA_LIST[1]

class ArgoverseDataset(Dataset):
    def __init__(self, data_dir, training, split_name='train', log_ids=["15c802a9-0f0e-3c87-b516-a3fa02f1ecb0"]):

        self.stereo_data_loader = ArgoverseStereoDataLoader(data_dir, split_name)
        self.training = training
        self.left_stereo_img_fpaths = []
        self.right_stereo_img_fpaths = []
        self.disparity_map_fpaths = []
        self.disparity_obj_map_fpaths = []
        for log_id in log_ids:
            if len(self.left_stereo_img_fpaths) == 0:
                self.left_stereo_img_fpaths = self.stereo_data_loader.get_ordered_log_stereo_image_fpaths(
                    log_id = log_id,
                    camera_name=STEREO_FRONT_LEFT_RECT
                )
                self.right_stereo_img_fpaths = self.stereo_data_loader.get_ordered_log_stereo_image_fpaths(
                    log_id = log_id, 
                    camera_name = STEREO_FRONT_RIGHT_RECT
                )

                self.disparity_map_fpaths = self.stereo_data_loader.get_ordered_log_disparity_map_fpaths(
                    log_id = log_id,
                    disparity_name="stereo_front_left_rect_disparity"
                )

                self.disparity_obj_map_fpaths = self.stereo_data_loader.get_ordered_log_disparity_map_fpaths(
                    log_id = log_id, 
                    disparity_name = "stereo_front_left_rect_objects_disparity"
                )
            else:
                self.left_stereo_img_fpaths = self.left_stereo_img_fpaths + self.stereo_data_loader.get_ordered_log_stereo_image_fpaths(
                        log_id = log_id,
                        camera_name=STEREO_FRONT_LEFT_RECT
                    )
                
                self.right_stereo_img_fpaths = self.right_stereo_img_fpaths + self.stereo_data_loader.get_ordered_log_stereo_image_fpaths(
                    log_id = log_id, 
                    camera_name = STEREO_FRONT_RIGHT_RECT
                )

                self.disparity_map_fpaths = self.disparity_map_fpaths+ self.stereo_data_loader.get_ordered_log_disparity_map_fpaths(
                    log_id = log_id,
                    disparity_name="stereo_front_left_rect_disparity"
                )

                self.disparity_obj_map_fpaths = self.disparity_obj_map_fpaths + self.stereo_data_loader.get_ordered_log_disparity_map_fpaths(
                    log_id = log_id, 
                    disparity_name = "stereo_front_left_rect_objects_disparity"
                )

    def load_path(self):
        print('loading path')
        #I believe this returns the paths for desired data
        #optional defintion
    def get_left_image(self, index, cropped=False):
        #Assumes that the cropping is consistent with test functionality
        left_img =  self.stereo_data_loader.get_rectified_stereo_image(self.left_stereo_img_fpaths[index])
        if cropped:
            crop_w, crop_h = 960, 512
            h, w , c = left_img.shape
            x_start = floor((w - crop_w)/2)
            y_start = floor((h - crop_h)/2)        
            left_img = left_img[y_start:y_start+crop_h, x_start:x_start+crop_w,:]
        
        return left_img

    def get_right_image(self, index, cropped=False):
        #Assumes that the cropping is consistent with test functionality
        right_img = self.stereo_data_loader.get_rectified_stereo_image(self.right_stereo_img_fpaths[index])
        if cropped:
            crop_w, crop_h = 960, 512
            h, w , c = right_img.shape
            x_start = floor((w - crop_w)/2)
            y_start = floor((h - crop_h)/2)        
            right_img = right_img[y_start:y_start+crop_h, x_start:x_start+crop_w,:]

        return right_img

    def get_disparity_image(self, index, cropped=False):
        stereo_front_left_rect_disparity = self.stereo_data_loader.get_disparity_map(self.disparity_map_fpaths[index])
        if cropped:
            crop_w, crop_h = 960, 512
            h, w  = stereo_front_left_rect_disparity.shape
            x_start = floor((w - crop_w)/2)
            y_start = floor((h - crop_h)/2)
            stereo_front_left_rect_disparity = stereo_front_left_rect_disparity[y_start:y_start+crop_h, x_start:x_start+crop_w]
        return stereo_front_left_rect_disparity


    def load_disp(self):
        #optinoal again, looks like it reads a depth map or disparity map
        #from a pfm (floating point image map file format), then returns that
        print('Loading disparity')
        
    def __len__(self):
        #specifies the length of the dataset
        return len(self.left_stereo_img_fpaths)
    def get_transform():
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]
        return transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std)])

    def __getitem__(self, index):
        #required function, expected return format of:
        #dictionary, with keys left (leftimg), right (rightimg),
        #   disparity (disparity), top_pad(seems like always 0), 
        #right_pad (seems like always 0), and left_filename (left image filename)
        left_img = self.stereo_data_loader.get_rectified_stereo_image(self.left_stereo_img_fpaths[index])
        right_img = self.stereo_data_loader.get_rectified_stereo_image(self.right_stereo_img_fpaths[index])
        stereo_front_left_rect_disparity = self.stereo_data_loader.get_disparity_map(self.disparity_map_fpaths[index])
        stereo_front_left_rect_objects_disparity = self.stereo_data_loader.get_disparity_map(self.disparity_obj_map_fpaths[index])

        mean = [0.485, 0.456, 0.406]

        std = [0.229, 0.224, 0.225]
        

        if self.training:
            #Need to crop...
            crop_w, crop_h = 512, 256
            h, w , c = left_img.shape
            #some number b/t 0 and all the way to edge (top or right)
            x1 = random.randint(0, w-crop_w)
            y1 = random.randint(0, h - crop_h)

            T = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(mean=mean, std=std)])
            
            left_img_t = T(left_img)
            left_img_t = transforms.functional.crop(left_img_t, y1, x1, crop_h, crop_w)
            right_img_t = T(right_img)
            right_img_t = transforms.functional.crop(right_img_t, y1, x1, crop_h, crop_w)
            #print('y1: ', y1, 'y1+crop_h', y1+crop_h, 'x1: ', x1, 'x1+crop_w', x1+crop_w)
            stereo_front_left_rect_disparity = stereo_front_left_rect_disparity[y1:y1+crop_h, x1:x1+crop_w]
            
            return {"left": left_img_t,
                "right": right_img_t,
                "disparity": stereo_front_left_rect_disparity}
        else:
            #Need to crop...
            crop_w, crop_h = 960, 512
            h, w , c = left_img.shape

            x_start = floor((w - crop_w)/2)
            y_start = floor((h - crop_h)/2)
            
            T = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(mean=mean, std=std)])

            #center crop:
            left_img_t = T(left_img)
            #print('y_start: ', y_start, 'x_start: ', x_start, 'crop_h: ', crop_h, 'crop_w:', crop_w)
            left_img_t = transforms.functional.crop(left_img_t, y_start, x_start, crop_h, crop_w)
            right_img_t = T(right_img)
            right_img_t = transforms.functional.crop(right_img_t, y_start, x_start, crop_h, crop_w)
            stereo_front_left_rect_disparity = stereo_front_left_rect_disparity[y_start:y_start+crop_h, x_start:x_start+crop_w]
            stereo_front_left_rect_objects_disparity = stereo_front_left_rect_objects_disparity[y_start:y_start+crop_h, x_start:x_start+crop_w]
            tmp_T = transforms.ToTensor()
            left_truth_image = tmp_T(self.get_left_image(index, cropped=True))
            right_truth_image = tmp_T(self.get_right_image(index, cropped=True))
            return {"left": left_img_t,
                "right": right_img_t,
                "disparity": stereo_front_left_rect_disparity,
                "disparity_obj": stereo_front_left_rect_objects_disparity,
                "top_pad": 0,
                "right_pad":0,
                "left_filename": self.left_stereo_img_fpaths[index],
                "left_truth_img": left_truth_image,
                "right_truth_img": right_truth_image}

# %%
#the 192 is default max disparity
max_disp = 192
# create summary logger
logdir = '.'
logger = SummaryWriter(logdir)

# %% [markdown]
# ### The following is for training, if already trained then skip to Test

# %%
data_dir = "/media/sf_shared/data"
split_name = "train"
log_ids = ['08a8b7f0-c317-3bdb-b3dc-b7c9b6d033e2', '0ef28d5c-ae34-370b-99e7-6709e1c4b929', '10b3a1d8-e56c-38be-aaf7-ef2f862a5c4e', 
'3138907e-1f8a-362f-8f3d-773f795a0d01',  'c6911883-1843-3727-8eaa-41dc8cda8993',
'3d20ae25-5b29-320d-8bae-f03e9dc177b9',  'cd38ac0b-c5a6-3743-a148-f4f7b804ed17',
'4137e94a-c5da-38bd-ad06-6d57b24bccd0',  'd4d9e91f-0f8e-334d-bd0e-0d062467308a',
'45753856-4575-4575-4575-345754906624',  'dcdcd8b3-0ba1-3218-b2ea-7bb965aad3f0',
'52af191b-ba56-326c-b569-e37790db40f3',  'de777454-df62-3d5a-a1ce-2edb5e5d4922',
'53037376-5303-5303-5303-553038557184',  'e9bb51af-1112-34c2-be3e-7ebe826649b4',
'53213cf0-540b-3b5a-9900-d24d1d41bda0',  'ebe7a98b-d383-343b-96d6-9e681e2c6a36',
'577ea60d-7cc0-34a4-a8ff-0401e5ab9c62',  'f0826a9f-f46e-3c27-97af-87a77f7899cd',
'5c251c22-11b2-3278-835c-0cf3cdee3f44',  'f3fb839e-0aa2-342b-81c3-312b80be44f9',
'649750f3-0163-34eb-a102-7aaf5384eaec',  'fa0b626f-03df-35a0-8447-021088814b8b',
'64c12551-adb9-36e3-a0c1-e43a0e9f3845']


argoverse_ds = ArgoverseDataset(data_dir, True, split_name, log_ids=log_ids)
TrainImgLoader = DataLoader(argoverse_ds, 1, shuffle=False, num_workers = 4)

# %%
model = __models__['MSNet2D'](max_disp)
learning_rate = .001
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999))

# %%
def train(TrainImgLoader, start_epoch = 0, epochs = 1, lrepochs= "200:10", summary_freq = 10, 
    train_limit = 100000, max_disp = 192, save_freq = 1):
    
    best_checkpoint_loss = 100
    for epoch_idx in range(start_epoch, epochs):
        adjust_learning_rate(optimizer, epoch_idx, learning_rate, lrepochs)
        for batch_idx, sample in enumerate(TrainImgLoader):
            global_step = len(TrainImgLoader) * epoch_idx + batch_idx
            start_time = time.time()
            do_summary = global_step % summary_freq == 0
            
            loss, scalar_outputs, image_outputs = train_sample(sample, compute_metrics=do_summary, max_disp=max_disp)
            if do_summary:
                save_scalars(logger, 'train', scalar_outputs, global_step)
                save_images(logger, 'train', image_outputs, global_step)
            del scalar_outputs, image_outputs
            print('Epoch {}/{}, Iter {}/{}, train loss = {:.3f}, time = {:.3f}'.format(epoch_idx, epochs,
                                                                                        batch_idx,
                                                                                        len(TrainImgLoader), loss,
                                                                                        time.time() - start_time))
            if batch_idx > train_limit:
                break  
        if (epoch_idx + 1)  % save_freq == 0:
            checkpoint_data = {'epoch': epoch_idx, 'model': model.state_dict(), 'optimizer': optimizer.state_dict()}
            torch.save(checkpoint_data, "{}/checkpoint_{:0>6}.ckpt".format(logdir, epoch_idx))

        gc.collect()

# %%
# train one sample
def train_sample(sample, max_disp = 192, compute_metrics=False):
    model.train()

    imgL, imgR, disp_gt = sample['left'], sample['right'], sample['disparity']

    optimizer.zero_grad()
    disp_ests = model(imgL, imgR)
    mask = (disp_gt < max_disp) & (disp_gt > 0)
    loss = model_loss(disp_ests, disp_gt, mask)

    scalar_outputs = {"loss": loss}
    image_outputs = {"disp_est": disp_ests, "disp_gt": disp_gt, "imgL": imgL, "imgR": imgR}
    if compute_metrics:
        with torch.no_grad():
            image_outputs["errormap"] = [disp_error_image_func(disp_est, disp_gt) for disp_est in disp_ests]
            scalar_outputs["EPE"] = [EPE_metric(disp_est, disp_gt, mask) for disp_est in disp_ests]
            scalar_outputs["D1"] = [D1_metric(disp_est, disp_gt, mask) for disp_est in disp_ests]
            scalar_outputs["Thres1"] = [Thres_metric(disp_est, disp_gt, mask, 1.0) for disp_est in disp_ests]
            scalar_outputs["Thres2"] = [Thres_metric(disp_est, disp_gt, mask, 2.0) for disp_est in disp_ests]
            scalar_outputs["Thres3"] = [Thres_metric(disp_est, disp_gt, mask, 3.0) for disp_est in disp_ests]
    loss.backward()
    optimizer.step()

    return tensor2float(loss), tensor2float(scalar_outputs), image_outputs

# %%
start_epoch = 0
epochs = 4
lrepochs = "4:10"
summary_freq = 10
save_freq = 1
train(TrainImgLoader, start_epoch = start_epoch, epochs = epochs, lrepochs= lrepochs, summary_freq = summary_freq, 
    max_disp = 192, save_freq = save_freq)
# Out:
# Downscale learning rate at epochs: [4], downscale rate: 10.0
# Setting learning rate to 0.001
# Epoch 0/4, Iter 0/2174, train loss = 99.976, time = 25.887
# Epoch 0/4, Iter 1/2174, train loss = 195.983, time = 14.913
# Epoch 0/4, Iter 2/2174, train loss = 194.900, time = 15.125
# Epoch 0/4, Iter 3/2174, train loss = nan, time = 15.004
# Epoch 0/4, Iter 4/2174, train loss = nan, time = 16.638
# Epoch 0/4, Iter 5/2174, train loss = 43.091, time = 14.287
# Epoch 0/4, Iter 6/2174, train loss = nan, time = 18.053
# Epoch 0/4, Iter 7/2174, train loss = nan, time = 14.124
# Epoch 0/4, Iter 8/2174, train loss = 66.427, time = 14.929
# Epoch 0/4, Iter 9/2174, train loss = 81.738, time = 16.358
# Epoch 0/4, Iter 10/2174, train loss = 47.595, time = 16.014
# Epoch 0/4, Iter 11/2174, train loss = 88.584, time = 14.321
# Epoch 0/4, Iter 12/2174, train loss = 33.964, time = 15.614
# Epoch 0/4, Iter 13/2174, train loss = nan, time = 14.093
# Epoch 0/4, Iter 14/2174, train loss = nan, time = 14.564
# Epoch 0/4, Iter 15/2174, train loss = nan, time = 13.846
# Epoch 0/4, Iter 16/2174, train loss = 69.415, time = 14.681
# Epoch 0/4, Iter 17/2174, train loss = 41.838, time = 17.002
# Epoch 0/4, Iter 18/2174, train loss = 89.290, time = 14.131
# Epoch 0/4, Iter 19/2174, train loss = nan, time = 14.137
# Epoch 0/4, Iter 20/2174, train loss = 99.896, time = 15.520
# Epoch 0/4, Iter 21/2174, train loss = 129.943, time = 14.614
# Epoch 0/4, Iter 22/2174, train loss = 67.515, time = 14.347
# Epoch 0/4, Iter 23/2174, train loss = 167.082, time = 17.698
# Epoch 0/4, Iter 24/2174, train loss = 147.655, time = 17.075
# Epoch 0/4, Iter 25/2174, train loss = 152.310, time = 14.428
# Epoch 0/4, Iter 26/2174, train loss = 162.617, time = 16.486
# Epoch 0/4, Iter 27/2174, train loss = 63.287, time = 15.117
# Epoch 0/4, Iter 28/2174, train loss = 125.282, time = 17.934
# Epoch 0/4, Iter 29/2174, train loss = 122.481, time = 19.342
# Epoch 0/4, Iter 30/2174, train loss = 102.420, time = 21.239
# Epoch 0/4, Iter 31/2174, train loss = nan, time = 14.313
# Epoch 0/4, Iter 32/2174, train loss = 90.057, time = 14.393
# Epoch 0/4, Iter 33/2174, train loss = 110.417, time = 14.510
# Epoch 0/4, Iter 34/2174, train loss = 168.846, time = 13.928
# Epoch 0/4, Iter 35/2174, train loss = 29.680, time = 13.561
# Epoch 0/4, Iter 36/2174, train loss = 40.926, time = 13.093
# Epoch 0/4, Iter 37/2174, train loss = 111.737, time = 13.663
# Epoch 0/4, Iter 38/2174, train loss = 96.564, time = 14.121
# Epoch 0/4, Iter 39/2174, train loss = 118.587, time = 16.229
# Epoch 0/4, Iter 40/2174, train loss = 76.372, time = 18.333
# Epoch 0/4, Iter 41/2174, train loss = nan, time = 13.689
# Epoch 0/4, Iter 42/2174, train loss = 53.015, time = 13.618
# Epoch 0/4, Iter 43/2174, train loss = 175.833, time = 13.941
# Epoch 0/4, Iter 44/2174, train loss = 222.582, time = 14.278
# Epoch 0/4, Iter 45/2174, train loss = 115.443, time = 13.565
# Epoch 0/4, Iter 46/2174, train loss = 69.841, time = 14.311
# Epoch 0/4, Iter 47/2174, train loss = nan, time = 14.037
# Epoch 0/4, Iter 48/2174, train loss = 126.953, time = 14.787
# Epoch 0/4, Iter 49/2174, train loss = 174.583, time = 16.594
# Epoch 0/4, Iter 50/2174, train loss = 169.172, time = 15.136
# Epoch 0/4, Iter 51/2174, train loss = 100.472, time = 13.407
# Epoch 0/4, Iter 52/2174, train loss = 164.958, time = 13.598
# Epoch 0/4, Iter 53/2174, train loss = nan, time = 14.012
# Epoch 0/4, Iter 54/2174, train loss = 110.906, time = 14.791
# Epoch 0/4, Iter 55/2174, train loss = nan, time = 12.666
# Epoch 0/4, Iter 56/2174, train loss = 127.940, time = 12.000
# Epoch 0/4, Iter 57/2174, train loss = 90.411, time = 12.366
# Epoch 0/4, Iter 58/2174, train loss = 36.414, time = 12.670
# Epoch 0/4, Iter 59/2174, train loss = nan, time = 13.007
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 60/2174, train loss = nan, time = 13.152
# Epoch 0/4, Iter 61/2174, train loss = 161.813, time = 12.977
# Epoch 0/4, Iter 62/2174, train loss = nan, time = 12.754
# Epoch 0/4, Iter 63/2174, train loss = 120.977, time = 12.851
# Epoch 0/4, Iter 64/2174, train loss = nan, time = 12.420
# Epoch 0/4, Iter 65/2174, train loss = nan, time = 12.594
# Epoch 0/4, Iter 66/2174, train loss = 94.699, time = 13.228
# Epoch 0/4, Iter 67/2174, train loss = 18.399, time = 12.597
# Epoch 0/4, Iter 68/2174, train loss = 212.857, time = 12.882
# Epoch 0/4, Iter 69/2174, train loss = nan, time = 12.662
# Epoch 0/4, Iter 70/2174, train loss = 195.335, time = 13.695
# Epoch 0/4, Iter 71/2174, train loss = 131.580, time = 12.161
# Epoch 0/4, Iter 72/2174, train loss = 98.174, time = 12.183
# Epoch 0/4, Iter 73/2174, train loss = nan, time = 12.797
# Epoch 0/4, Iter 74/2174, train loss = 171.313, time = 12.240
# Epoch 0/4, Iter 75/2174, train loss = 19.205, time = 12.195
# Epoch 0/4, Iter 76/2174, train loss = 45.512, time = 12.208
# Epoch 0/4, Iter 77/2174, train loss = nan, time = 12.610
# Epoch 0/4, Iter 78/2174, train loss = nan, time = 12.880
# Epoch 0/4, Iter 79/2174, train loss = 91.107, time = 12.210
# Epoch 0/4, Iter 80/2174, train loss = 23.150, time = 12.932
# Epoch 0/4, Iter 81/2174, train loss = 17.499, time = 12.129
# Epoch 0/4, Iter 82/2174, train loss = 32.302, time = 12.397
# Epoch 0/4, Iter 83/2174, train loss = nan, time = 12.670
# Epoch 0/4, Iter 84/2174, train loss = 75.172, time = 12.269
# Epoch 0/4, Iter 85/2174, train loss = 24.461, time = 12.841
# Epoch 0/4, Iter 86/2174, train loss = 55.592, time = 12.677
# Epoch 0/4, Iter 87/2174, train loss = 79.282, time = 12.466
# Epoch 0/4, Iter 88/2174, train loss = 67.685, time = 12.995
# Epoch 0/4, Iter 89/2174, train loss = 53.183, time = 12.243
# Epoch 0/4, Iter 90/2174, train loss = 29.252, time = 13.074
# Epoch 0/4, Iter 91/2174, train loss = 57.547, time = 12.210
# Epoch 0/4, Iter 92/2174, train loss = 41.124, time = 12.222
# Epoch 0/4, Iter 93/2174, train loss = 55.617, time = 13.517
# Epoch 0/4, Iter 94/2174, train loss = 39.062, time = 13.865
# Epoch 0/4, Iter 95/2174, train loss = 162.539, time = 15.340
# Epoch 0/4, Iter 96/2174, train loss = 87.500, time = 20.762
# Epoch 0/4, Iter 97/2174, train loss = 86.704, time = 16.606
# Epoch 0/4, Iter 98/2174, train loss = 198.824, time = 20.242
# Epoch 0/4, Iter 99/2174, train loss = 35.578, time = 18.235
# Epoch 0/4, Iter 100/2174, train loss = 55.558, time = 20.448
# Epoch 0/4, Iter 101/2174, train loss = 77.960, time = 17.750
# Epoch 0/4, Iter 102/2174, train loss = 64.427, time = 19.051
# Epoch 0/4, Iter 103/2174, train loss = 44.666, time = 16.199
# Epoch 0/4, Iter 104/2174, train loss = 60.604, time = 18.585
# Epoch 0/4, Iter 105/2174, train loss = 93.850, time = 15.611
# Epoch 0/4, Iter 106/2174, train loss = 155.703, time = 15.438
# Epoch 0/4, Iter 107/2174, train loss = 38.023, time = 15.083
# Epoch 0/4, Iter 108/2174, train loss = 139.225, time = 17.884
# Epoch 0/4, Iter 109/2174, train loss = 150.141, time = 18.327
# Epoch 0/4, Iter 110/2174, train loss = 41.111, time = 15.544
# Epoch 0/4, Iter 111/2174, train loss = nan, time = 17.407
# Epoch 0/4, Iter 112/2174, train loss = 82.867, time = 14.485
# Epoch 0/4, Iter 113/2174, train loss = nan, time = 12.664
# Epoch 0/4, Iter 114/2174, train loss = 150.260, time = 14.435
# Epoch 0/4, Iter 115/2174, train loss = 171.057, time = 13.593
# Epoch 0/4, Iter 116/2174, train loss = 47.792, time = 13.691
# Epoch 0/4, Iter 117/2174, train loss = 174.728, time = 14.021
# Epoch 0/4, Iter 118/2174, train loss = 219.751, time = 13.895
# Epoch 0/4, Iter 119/2174, train loss = nan, time = 13.167
# Epoch 0/4, Iter 120/2174, train loss = 126.664, time = 14.648
# Epoch 0/4, Iter 121/2174, train loss = 37.938, time = 12.748
# Epoch 0/4, Iter 122/2174, train loss = 56.240, time = 13.403
# Epoch 0/4, Iter 123/2174, train loss = 180.242, time = 14.035
# Epoch 0/4, Iter 124/2174, train loss = 27.679, time = 14.252
# Epoch 0/4, Iter 125/2174, train loss = 30.678, time = 13.802
# Epoch 0/4, Iter 126/2174, train loss = nan, time = 13.178
# Epoch 0/4, Iter 127/2174, train loss = 112.838, time = 12.718
# Epoch 0/4, Iter 128/2174, train loss = 62.148, time = 12.716
# Epoch 0/4, Iter 129/2174, train loss = 91.950, time = 14.827
# Epoch 0/4, Iter 130/2174, train loss = 115.243, time = 18.542
# Epoch 0/4, Iter 131/2174, train loss = 108.601, time = 13.354
# Epoch 0/4, Iter 132/2174, train loss = 112.588, time = 14.141
# Epoch 0/4, Iter 133/2174, train loss = 145.933, time = 16.699
# Epoch 0/4, Iter 134/2174, train loss = 50.130, time = 13.722
# Epoch 0/4, Iter 135/2174, train loss = 133.559, time = 13.067
# Epoch 0/4, Iter 136/2174, train loss = 210.305, time = 12.755
# Epoch 0/4, Iter 137/2174, train loss = 154.655, time = 12.545
# Epoch 0/4, Iter 138/2174, train loss = nan, time = 12.404
# Epoch 0/4, Iter 139/2174, train loss = 207.702, time = 16.182
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 140/2174, train loss = nan, time = 13.526
# Epoch 0/4, Iter 141/2174, train loss = 134.462, time = 12.734
# Epoch 0/4, Iter 142/2174, train loss = 80.969, time = 12.438
# Epoch 0/4, Iter 143/2174, train loss = nan, time = 13.106
# Epoch 0/4, Iter 144/2174, train loss = nan, time = 14.313
# Epoch 0/4, Iter 145/2174, train loss = 61.054, time = 12.554
# Epoch 0/4, Iter 146/2174, train loss = nan, time = 12.490
# Epoch 0/4, Iter 147/2174, train loss = nan, time = 12.813
# Epoch 0/4, Iter 148/2174, train loss = nan, time = 12.675
# Epoch 0/4, Iter 149/2174, train loss = nan, time = 13.720
# Epoch 0/4, Iter 150/2174, train loss = 40.287, time = 15.994
# Epoch 0/4, Iter 151/2174, train loss = nan, time = 12.394
# Epoch 0/4, Iter 152/2174, train loss = nan, time = 12.786
# Epoch 0/4, Iter 153/2174, train loss = 76.599, time = 13.069
# Epoch 0/4, Iter 154/2174, train loss = 126.960, time = 13.052
# Epoch 0/4, Iter 155/2174, train loss = 80.448, time = 16.093
# Epoch 0/4, Iter 156/2174, train loss = nan, time = 13.001
# Epoch 0/4, Iter 157/2174, train loss = 99.107, time = 12.989
# Epoch 0/4, Iter 158/2174, train loss = nan, time = 13.048
# Epoch 0/4, Iter 159/2174, train loss = 139.082, time = 13.208
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 160/2174, train loss = nan, time = 13.003
# Epoch 0/4, Iter 161/2174, train loss = 94.504, time = 12.382
# Epoch 0/4, Iter 162/2174, train loss = nan, time = 12.337
# Epoch 0/4, Iter 163/2174, train loss = 65.130, time = 12.165
# Epoch 0/4, Iter 164/2174, train loss = nan, time = 12.831
# Epoch 0/4, Iter 165/2174, train loss = 57.796, time = 12.350
# Epoch 0/4, Iter 166/2174, train loss = 59.242, time = 12.421
# Epoch 0/4, Iter 167/2174, train loss = 90.899, time = 12.812
# Epoch 0/4, Iter 168/2174, train loss = 156.947, time = 12.825
# Epoch 0/4, Iter 169/2174, train loss = nan, time = 12.231
# Epoch 0/4, Iter 170/2174, train loss = 149.894, time = 13.130
# Epoch 0/4, Iter 171/2174, train loss = nan, time = 12.145
# Epoch 0/4, Iter 172/2174, train loss = 67.536, time = 12.567
# Epoch 0/4, Iter 173/2174, train loss = 173.344, time = 12.445
# Epoch 0/4, Iter 174/2174, train loss = 199.387, time = 12.886
# Epoch 0/4, Iter 175/2174, train loss = 30.474, time = 12.351
# Epoch 0/4, Iter 176/2174, train loss = 184.053, time = 12.219
# Epoch 0/4, Iter 177/2174, train loss = 85.940, time = 12.141
# Epoch 0/4, Iter 178/2174, train loss = 75.955, time = 12.860
# Epoch 0/4, Iter 179/2174, train loss = nan, time = 14.342
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 180/2174, train loss = nan, time = 12.925
# Epoch 0/4, Iter 181/2174, train loss = nan, time = 12.034
# Epoch 0/4, Iter 182/2174, train loss = nan, time = 12.255
# Epoch 0/4, Iter 183/2174, train loss = 241.576, time = 12.918
# Epoch 0/4, Iter 184/2174, train loss = nan, time = 12.775
# Epoch 0/4, Iter 185/2174, train loss = 30.943, time = 12.473
# Epoch 0/4, Iter 186/2174, train loss = nan, time = 12.475
# Epoch 0/4, Iter 187/2174, train loss = 207.946, time = 11.967
# Epoch 0/4, Iter 188/2174, train loss = 54.719, time = 12.082
# Epoch 0/4, Iter 189/2174, train loss = 182.888, time = 13.456
# Epoch 0/4, Iter 190/2174, train loss = 71.256, time = 13.287
# Epoch 0/4, Iter 191/2174, train loss = 154.237, time = 12.353
# Epoch 0/4, Iter 192/2174, train loss = 22.472, time = 16.158
# Epoch 0/4, Iter 193/2174, train loss = 92.206, time = 12.702
# Epoch 0/4, Iter 194/2174, train loss = 94.711, time = 12.900
# Epoch 0/4, Iter 195/2174, train loss = 83.569, time = 12.224
# Epoch 0/4, Iter 196/2174, train loss = nan, time = 11.971
# Epoch 0/4, Iter 197/2174, train loss = 67.171, time = 12.530
# Epoch 0/4, Iter 198/2174, train loss = 51.297, time = 12.118
# Epoch 0/4, Iter 199/2174, train loss = nan, time = 14.531
# Epoch 0/4, Iter 200/2174, train loss = 80.973, time = 13.577
# Epoch 0/4, Iter 201/2174, train loss = 44.545, time = 12.140
# Epoch 0/4, Iter 202/2174, train loss = 43.610, time = 13.288
# Epoch 0/4, Iter 203/2174, train loss = 129.932, time = 12.824
# Epoch 0/4, Iter 204/2174, train loss = 60.101, time = 12.363
# Epoch 0/4, Iter 205/2174, train loss = 11.109, time = 16.113
# Epoch 0/4, Iter 206/2174, train loss = nan, time = 12.840
# Epoch 0/4, Iter 207/2174, train loss = 154.043, time = 12.476
# Epoch 0/4, Iter 208/2174, train loss = 206.560, time = 12.103
# Epoch 0/4, Iter 209/2174, train loss = 127.716, time = 12.265
# Epoch 0/4, Iter 210/2174, train loss = 32.444, time = 12.946
# Epoch 0/4, Iter 211/2174, train loss = 62.671, time = 11.956
# Epoch 0/4, Iter 212/2174, train loss = nan, time = 12.661
# Epoch 0/4, Iter 213/2174, train loss = 189.984, time = 12.493
# Epoch 0/4, Iter 214/2174, train loss = 16.665, time = 13.272
# Epoch 0/4, Iter 215/2174, train loss = 38.634, time = 13.090
# Epoch 0/4, Iter 216/2174, train loss = 67.705, time = 12.775
# Epoch 0/4, Iter 217/2174, train loss = 27.941, time = 12.926
# Epoch 0/4, Iter 218/2174, train loss = nan, time = 12.857
# Epoch 0/4, Iter 219/2174, train loss = 75.331, time = 12.675
# Epoch 0/4, Iter 220/2174, train loss = 214.608, time = 13.158
# Epoch 0/4, Iter 221/2174, train loss = nan, time = 11.909
# Epoch 0/4, Iter 222/2174, train loss = 62.512, time = 11.963
# Epoch 0/4, Iter 223/2174, train loss = nan, time = 12.445
# Epoch 0/4, Iter 224/2174, train loss = 85.608, time = 13.501
# Epoch 0/4, Iter 225/2174, train loss = nan, time = 12.025
# Epoch 0/4, Iter 226/2174, train loss = nan, time = 12.027
# Epoch 0/4, Iter 227/2174, train loss = nan, time = 12.423
# Epoch 0/4, Iter 228/2174, train loss = 78.295, time = 12.016
# Epoch 0/4, Iter 229/2174, train loss = 144.951, time = 12.548
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 230/2174, train loss = nan, time = 13.032
# Epoch 0/4, Iter 231/2174, train loss = nan, time = 12.165
# Epoch 0/4, Iter 232/2174, train loss = 61.749, time = 12.137
# Epoch 0/4, Iter 233/2174, train loss = 156.701, time = 12.121
# Epoch 0/4, Iter 234/2174, train loss = nan, time = 12.132
# Epoch 0/4, Iter 235/2174, train loss = nan, time = 12.562
# Epoch 0/4, Iter 236/2174, train loss = nan, time = 12.548
# Epoch 0/4, Iter 237/2174, train loss = 37.306, time = 12.232
# Epoch 0/4, Iter 238/2174, train loss = nan, time = 12.546
# Epoch 0/4, Iter 239/2174, train loss = nan, time = 12.840
# Epoch 0/4, Iter 240/2174, train loss = 189.370, time = 13.149
# Epoch 0/4, Iter 241/2174, train loss = nan, time = 15.836
# Epoch 0/4, Iter 242/2174, train loss = 183.318, time = 12.627
# Epoch 0/4, Iter 243/2174, train loss = 165.154, time = 11.998
# Epoch 0/4, Iter 244/2174, train loss = nan, time = 12.560
# Epoch 0/4, Iter 245/2174, train loss = 143.201, time = 13.023
# Epoch 0/4, Iter 246/2174, train loss = 63.405, time = 12.813
# Epoch 0/4, Iter 247/2174, train loss = 181.595, time = 12.097
# Epoch 0/4, Iter 248/2174, train loss = 116.701, time = 12.119
# Epoch 0/4, Iter 249/2174, train loss = 175.091, time = 12.402
# Epoch 0/4, Iter 250/2174, train loss = 156.409, time = 13.560
# Epoch 0/4, Iter 251/2174, train loss = 128.983, time = 12.154
# Epoch 0/4, Iter 252/2174, train loss = nan, time = 11.800
# Epoch 0/4, Iter 253/2174, train loss = 68.425, time = 12.063
# Epoch 0/4, Iter 254/2174, train loss = 65.367, time = 12.590
# Epoch 0/4, Iter 255/2174, train loss = 47.162, time = 12.992
# Epoch 0/4, Iter 256/2174, train loss = nan, time = 12.380
# Epoch 0/4, Iter 257/2174, train loss = 42.922, time = 12.277
# Epoch 0/4, Iter 258/2174, train loss = 76.730, time = 12.447
# Epoch 0/4, Iter 259/2174, train loss = nan, time = 13.119
# Epoch 0/4, Iter 260/2174, train loss = 142.603, time = 13.533
# Epoch 0/4, Iter 261/2174, train loss = 166.861, time = 12.042
# Epoch 0/4, Iter 262/2174, train loss = 73.381, time = 12.166
# Epoch 0/4, Iter 263/2174, train loss = 50.230, time = 11.985
# Epoch 0/4, Iter 264/2174, train loss = 167.608, time = 12.391
# Epoch 0/4, Iter 265/2174, train loss = 154.563, time = 16.039
# Epoch 0/4, Iter 266/2174, train loss = nan, time = 12.353
# Epoch 0/4, Iter 267/2174, train loss = 80.345, time = 12.049
# Epoch 0/4, Iter 268/2174, train loss = 54.905, time = 12.624
# Epoch 0/4, Iter 269/2174, train loss = 182.448, time = 12.339
# Epoch 0/4, Iter 270/2174, train loss = 183.091, time = 12.859
# Epoch 0/4, Iter 271/2174, train loss = 52.987, time = 11.974
# Epoch 0/4, Iter 272/2174, train loss = 118.311, time = 12.651
# Epoch 0/4, Iter 273/2174, train loss = nan, time = 12.001
# Epoch 0/4, Iter 274/2174, train loss = 159.612, time = 12.791
# Epoch 0/4, Iter 275/2174, train loss = nan, time = 12.356
# Epoch 0/4, Iter 276/2174, train loss = 119.595, time = 12.190
# Epoch 0/4, Iter 277/2174, train loss = 153.058, time = 12.918
# Epoch 0/4, Iter 278/2174, train loss = 57.838, time = 12.289
# Epoch 0/4, Iter 279/2174, train loss = 92.592, time = 11.977
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 280/2174, train loss = nan, time = 13.940
# Epoch 0/4, Iter 281/2174, train loss = 48.064, time = 12.087
# Epoch 0/4, Iter 282/2174, train loss = 138.124, time = 12.854
# Epoch 0/4, Iter 283/2174, train loss = 209.092, time = 12.416
# Epoch 0/4, Iter 284/2174, train loss = nan, time = 12.660
# Epoch 0/4, Iter 285/2174, train loss = 110.564, time = 14.828
# Epoch 0/4, Iter 286/2174, train loss = 50.655, time = 12.105
# Epoch 0/4, Iter 287/2174, train loss = nan, time = 12.813
# Epoch 0/4, Iter 288/2174, train loss = nan, time = 12.595
# Epoch 0/4, Iter 289/2174, train loss = 154.794, time = 12.268
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 290/2174, train loss = nan, time = 14.066
# Epoch 0/4, Iter 291/2174, train loss = 130.252, time = 12.067
# Epoch 0/4, Iter 292/2174, train loss = nan, time = 12.586
# Epoch 0/4, Iter 293/2174, train loss = 95.650, time = 12.136
# Epoch 0/4, Iter 294/2174, train loss = 89.276, time = 12.215
# Epoch 0/4, Iter 295/2174, train loss = 95.870, time = 14.486
# Epoch 0/4, Iter 296/2174, train loss = nan, time = 12.192
# Epoch 0/4, Iter 297/2174, train loss = 239.947, time = 12.037
# Epoch 0/4, Iter 298/2174, train loss = 80.600, time = 12.094
# Epoch 0/4, Iter 299/2174, train loss = 220.941, time = 12.048
# Epoch 0/4, Iter 300/2174, train loss = 45.476, time = 13.266
# Epoch 0/4, Iter 301/2174, train loss = 59.011, time = 12.336
# Epoch 0/4, Iter 302/2174, train loss = 46.363, time = 12.414
# Epoch 0/4, Iter 303/2174, train loss = nan, time = 12.502
# Epoch 0/4, Iter 304/2174, train loss = 160.020, time = 12.622
# Epoch 0/4, Iter 305/2174, train loss = 119.333, time = 12.632
# Epoch 0/4, Iter 306/2174, train loss = 144.175, time = 12.468
# Epoch 0/4, Iter 307/2174, train loss = 33.228, time = 12.102
# Epoch 0/4, Iter 308/2174, train loss = 102.824, time = 13.066
# Epoch 0/4, Iter 309/2174, train loss = 99.543, time = 12.595
# Epoch 0/4, Iter 310/2174, train loss = 142.099, time = 12.637
# Epoch 0/4, Iter 311/2174, train loss = nan, time = 12.777
# Epoch 0/4, Iter 312/2174, train loss = 122.399, time = 12.556
# Epoch 0/4, Iter 313/2174, train loss = nan, time = 11.996
# Epoch 0/4, Iter 314/2174, train loss = 65.257, time = 12.519
# Epoch 0/4, Iter 315/2174, train loss = nan, time = 11.962
# Epoch 0/4, Iter 316/2174, train loss = 57.152, time = 12.895
# Epoch 0/4, Iter 317/2174, train loss = 30.543, time = 12.292
# Epoch 0/4, Iter 318/2174, train loss = nan, time = 12.035
# Epoch 0/4, Iter 319/2174, train loss = 35.995, time = 12.457
# Epoch 0/4, Iter 320/2174, train loss = 48.868, time = 12.434
# Epoch 0/4, Iter 321/2174, train loss = 147.104, time = 12.309
# Epoch 0/4, Iter 322/2174, train loss = nan, time = 12.108
# Epoch 0/4, Iter 323/2174, train loss = 122.376, time = 12.364
# Epoch 0/4, Iter 324/2174, train loss = 48.496, time = 12.598
# Epoch 0/4, Iter 325/2174, train loss = 95.865, time = 12.919
# Epoch 0/4, Iter 326/2174, train loss = 100.581, time = 12.281
# Epoch 0/4, Iter 327/2174, train loss = 70.039, time = 12.024
# Epoch 0/4, Iter 328/2174, train loss = 163.257, time = 12.419
# Epoch 0/4, Iter 329/2174, train loss = 30.432, time = 15.563
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 330/2174, train loss = nan, time = 12.782
# Epoch 0/4, Iter 331/2174, train loss = 175.791, time = 12.488
# Epoch 0/4, Iter 332/2174, train loss = 38.832, time = 12.003
# Epoch 0/4, Iter 333/2174, train loss = nan, time = 12.689
# Epoch 0/4, Iter 334/2174, train loss = 109.072, time = 11.919
# Epoch 0/4, Iter 335/2174, train loss = 110.394, time = 12.824
# Epoch 0/4, Iter 336/2174, train loss = 74.291, time = 16.555
# Epoch 0/4, Iter 337/2174, train loss = 34.951, time = 12.820
# Epoch 0/4, Iter 338/2174, train loss = 224.021, time = 14.597
# Epoch 0/4, Iter 339/2174, train loss = 76.327, time = 12.276
# Epoch 0/4, Iter 340/2174, train loss = 26.172, time = 12.746
# Epoch 0/4, Iter 341/2174, train loss = nan, time = 12.365
# Epoch 0/4, Iter 342/2174, train loss = 57.968, time = 12.547
# Epoch 0/4, Iter 343/2174, train loss = nan, time = 11.947
# Epoch 0/4, Iter 344/2174, train loss = nan, time = 12.038
# Epoch 0/4, Iter 345/2174, train loss = 117.130, time = 11.936
# Epoch 0/4, Iter 346/2174, train loss = 39.436, time = 12.571
# Epoch 0/4, Iter 347/2174, train loss = 50.814, time = 12.049
# Epoch 0/4, Iter 348/2174, train loss = nan, time = 12.055
# Epoch 0/4, Iter 349/2174, train loss = nan, time = 12.216
# Epoch 0/4, Iter 350/2174, train loss = 79.164, time = 13.034
# Epoch 0/4, Iter 351/2174, train loss = nan, time = 12.498
# Epoch 0/4, Iter 352/2174, train loss = 67.134, time = 12.121
# Epoch 0/4, Iter 353/2174, train loss = 53.413, time = 12.067
# Epoch 0/4, Iter 354/2174, train loss = 72.483, time = 11.977
# Epoch 0/4, Iter 355/2174, train loss = 235.871, time = 12.782
# Epoch 0/4, Iter 356/2174, train loss = 40.884, time = 14.852
# Epoch 0/4, Iter 357/2174, train loss = 112.299, time = 12.554
# Epoch 0/4, Iter 358/2174, train loss = 116.381, time = 11.998
# Epoch 0/4, Iter 359/2174, train loss = 169.364, time = 12.027
# Epoch 0/4, Iter 360/2174, train loss = 70.118, time = 13.075
# Epoch 0/4, Iter 361/2174, train loss = 44.229, time = 12.157
# Epoch 0/4, Iter 362/2174, train loss = 69.372, time = 12.937
# Epoch 0/4, Iter 363/2174, train loss = 200.192, time = 12.508
# Epoch 0/4, Iter 364/2174, train loss = 99.297, time = 11.861
# Epoch 0/4, Iter 365/2174, train loss = nan, time = 11.810
# Epoch 0/4, Iter 366/2174, train loss = nan, time = 13.249
# Epoch 0/4, Iter 367/2174, train loss = 107.593, time = 12.761
# Epoch 0/4, Iter 368/2174, train loss = 150.421, time = 12.338
# Epoch 0/4, Iter 369/2174, train loss = 66.183, time = 12.859
# Epoch 0/4, Iter 370/2174, train loss = 58.818, time = 13.209
# Epoch 0/4, Iter 371/2174, train loss = 121.425, time = 11.896
# Epoch 0/4, Iter 372/2174, train loss = nan, time = 12.099
# Epoch 0/4, Iter 373/2174, train loss = nan, time = 11.772
# Epoch 0/4, Iter 374/2174, train loss = 69.505, time = 12.825
# Epoch 0/4, Iter 375/2174, train loss = 137.355, time = 12.556
# Epoch 0/4, Iter 376/2174, train loss = 191.002, time = 11.988
# Epoch 0/4, Iter 377/2174, train loss = 126.665, time = 13.297
# Epoch 0/4, Iter 378/2174, train loss = 196.660, time = 12.041
# Epoch 0/4, Iter 379/2174, train loss = 78.734, time = 12.039
# Epoch 0/4, Iter 380/2174, train loss = 109.094, time = 12.855
# Epoch 0/4, Iter 381/2174, train loss = 56.537, time = 12.276
# Epoch 0/4, Iter 382/2174, train loss = 44.162, time = 13.166
# Epoch 0/4, Iter 383/2174, train loss = 146.283, time = 12.274
# Epoch 0/4, Iter 384/2174, train loss = 33.802, time = 12.351
# Epoch 0/4, Iter 385/2174, train loss = 142.441, time = 11.997
# Epoch 0/4, Iter 386/2174, train loss = 56.002, time = 12.477
# Epoch 0/4, Iter 387/2174, train loss = 161.775, time = 13.261
# Epoch 0/4, Iter 388/2174, train loss = 107.028, time = 14.947
# Epoch 0/4, Iter 389/2174, train loss = 101.655, time = 12.399
# Epoch 0/4, Iter 390/2174, train loss = 117.499, time = 13.334
# Epoch 0/4, Iter 391/2174, train loss = 85.185, time = 11.747
# Epoch 0/4, Iter 392/2174, train loss = 29.415, time = 12.738
# Epoch 0/4, Iter 393/2174, train loss = 172.042, time = 12.223
# Epoch 0/4, Iter 394/2174, train loss = nan, time = 12.377
# Epoch 0/4, Iter 395/2174, train loss = 127.604, time = 11.803
# Epoch 0/4, Iter 396/2174, train loss = nan, time = 11.798
# Epoch 0/4, Iter 397/2174, train loss = 124.666, time = 14.998
# Epoch 0/4, Iter 398/2174, train loss = nan, time = 12.506
# Epoch 0/4, Iter 399/2174, train loss = nan, time = 12.524
# Epoch 0/4, Iter 400/2174, train loss = 137.803, time = 13.153
# Epoch 0/4, Iter 401/2174, train loss = 208.631, time = 11.884
# Epoch 0/4, Iter 402/2174, train loss = 138.643, time = 14.493
# Epoch 0/4, Iter 403/2174, train loss = 106.555, time = 12.079
# Epoch 0/4, Iter 404/2174, train loss = 114.113, time = 15.553
# Epoch 0/4, Iter 405/2174, train loss = 22.435, time = 12.509
# Epoch 0/4, Iter 406/2174, train loss = 48.486, time = 12.894
# Epoch 0/4, Iter 407/2174, train loss = 159.710, time = 12.181
# Epoch 0/4, Iter 408/2174, train loss = 161.652, time = 15.024
# Epoch 0/4, Iter 409/2174, train loss = 27.801, time = 11.925
# Epoch 0/4, Iter 410/2174, train loss = 90.739, time = 12.664
# Epoch 0/4, Iter 411/2174, train loss = 45.817, time = 11.993
# Epoch 0/4, Iter 412/2174, train loss = 133.422, time = 12.359
# Epoch 0/4, Iter 413/2174, train loss = 71.005, time = 12.086
# Epoch 0/4, Iter 414/2174, train loss = 147.245, time = 12.572
# Epoch 0/4, Iter 415/2174, train loss = nan, time = 12.430
# Epoch 0/4, Iter 416/2174, train loss = nan, time = 11.889
# Epoch 0/4, Iter 417/2174, train loss = nan, time = 13.140
# Epoch 0/4, Iter 418/2174, train loss = 72.088, time = 11.996
# Epoch 0/4, Iter 419/2174, train loss = 121.323, time = 11.869
# Epoch 0/4, Iter 420/2174, train loss = 96.999, time = 12.565
# Epoch 0/4, Iter 421/2174, train loss = 135.801, time = 11.960
# Epoch 0/4, Iter 422/2174, train loss = 37.656, time = 15.276
# Epoch 0/4, Iter 423/2174, train loss = 87.714, time = 12.561
# Epoch 0/4, Iter 424/2174, train loss = 117.788, time = 11.963
# Epoch 0/4, Iter 425/2174, train loss = nan, time = 14.350
# Epoch 0/4, Iter 426/2174, train loss = nan, time = 12.510
# Epoch 0/4, Iter 427/2174, train loss = 132.866, time = 13.096
# Epoch 0/4, Iter 428/2174, train loss = 89.781, time = 12.117
# Epoch 0/4, Iter 429/2174, train loss = 88.548, time = 11.935
# Epoch 0/4, Iter 430/2174, train loss = 194.648, time = 12.401
# Epoch 0/4, Iter 431/2174, train loss = 88.970, time = 12.011
# Epoch 0/4, Iter 432/2174, train loss = 143.853, time = 12.147
# Epoch 0/4, Iter 433/2174, train loss = nan, time = 12.618
# Epoch 0/4, Iter 434/2174, train loss = 68.718, time = 12.456
# Epoch 0/4, Iter 435/2174, train loss = 151.189, time = 12.777
# Epoch 0/4, Iter 436/2174, train loss = nan, time = 12.778
# Epoch 0/4, Iter 437/2174, train loss = 39.079, time = 11.970
# Epoch 0/4, Iter 438/2174, train loss = 37.637, time = 12.633
# Epoch 0/4, Iter 439/2174, train loss = 90.452, time = 12.479
# Epoch 0/4, Iter 440/2174, train loss = 64.358, time = 12.659
# Epoch 0/4, Iter 441/2174, train loss = 55.968, time = 12.000
# Epoch 0/4, Iter 442/2174, train loss = 179.048, time = 11.967
# Epoch 0/4, Iter 443/2174, train loss = nan, time = 12.219
# Epoch 0/4, Iter 444/2174, train loss = 69.119, time = 12.012
# Epoch 0/4, Iter 445/2174, train loss = 49.488, time = 12.745
# Epoch 0/4, Iter 446/2174, train loss = 172.377, time = 12.707
# Epoch 0/4, Iter 447/2174, train loss = 54.150, time = 12.247
# Epoch 0/4, Iter 448/2174, train loss = 52.516, time = 13.177
# Epoch 0/4, Iter 449/2174, train loss = 37.544, time = 12.059
# Epoch 0/4, Iter 450/2174, train loss = 42.980, time = 13.212
# Epoch 0/4, Iter 451/2174, train loss = 105.959, time = 12.049
# Epoch 0/4, Iter 452/2174, train loss = 134.787, time = 12.036
# Epoch 0/4, Iter 453/2174, train loss = 33.790, time = 12.396
# Epoch 0/4, Iter 454/2174, train loss = 67.727, time = 15.913
# Epoch 0/4, Iter 455/2174, train loss = 124.110, time = 12.237
# Epoch 0/4, Iter 456/2174, train loss = 70.420, time = 11.890
# Epoch 0/4, Iter 457/2174, train loss = 125.678, time = 12.270
# Epoch 0/4, Iter 458/2174, train loss = 104.355, time = 12.598
# Epoch 0/4, Iter 459/2174, train loss = 47.955, time = 12.047
# Epoch 0/4, Iter 460/2174, train loss = 111.203, time = 12.462
# Epoch 0/4, Iter 461/2174, train loss = 52.662, time = 12.028
# Epoch 0/4, Iter 462/2174, train loss = 76.181, time = 12.496
# Epoch 0/4, Iter 463/2174, train loss = 144.110, time = 13.511
# Epoch 0/4, Iter 464/2174, train loss = 102.676, time = 12.241
# Epoch 0/4, Iter 465/2174, train loss = 57.616, time = 12.101
# Epoch 0/4, Iter 466/2174, train loss = nan, time = 12.066
# Epoch 0/4, Iter 467/2174, train loss = 114.827, time = 12.055
# Epoch 0/4, Iter 468/2174, train loss = 138.073, time = 11.925
# Epoch 0/4, Iter 469/2174, train loss = nan, time = 12.473
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 470/2174, train loss = nan, time = 12.477
# Epoch 0/4, Iter 471/2174, train loss = nan, time = 12.108
# Epoch 0/4, Iter 472/2174, train loss = 98.983, time = 11.860
# Epoch 0/4, Iter 473/2174, train loss = 35.563, time = 12.250
# Epoch 0/4, Iter 474/2174, train loss = 97.738, time = 12.699
# Epoch 0/4, Iter 475/2174, train loss = 219.179, time = 12.440
# Epoch 0/4, Iter 476/2174, train loss = 99.037, time = 12.534
# Epoch 0/4, Iter 477/2174, train loss = 116.932, time = 12.062
# Epoch 0/4, Iter 478/2174, train loss = 62.246, time = 12.698
# Epoch 0/4, Iter 479/2174, train loss = 45.786, time = 12.323
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 480/2174, train loss = nan, time = 12.794
# Epoch 0/4, Iter 481/2174, train loss = nan, time = 12.090
# Epoch 0/4, Iter 482/2174, train loss = nan, time = 11.964
# Epoch 0/4, Iter 483/2174, train loss = 51.444, time = 12.183
# Epoch 0/4, Iter 484/2174, train loss = 61.050, time = 12.784
# Epoch 0/4, Iter 485/2174, train loss = 32.979, time = 12.228
# Epoch 0/4, Iter 486/2174, train loss = 21.261, time = 12.025
# Epoch 0/4, Iter 487/2174, train loss = 98.618, time = 12.368
# Epoch 0/4, Iter 488/2174, train loss = nan, time = 12.340
# Epoch 0/4, Iter 489/2174, train loss = 59.716, time = 14.713
# Epoch 0/4, Iter 490/2174, train loss = 149.875, time = 13.285
# Epoch 0/4, Iter 491/2174, train loss = 10.181, time = 12.190
# Epoch 0/4, Iter 492/2174, train loss = 44.601, time = 12.019
# Epoch 0/4, Iter 493/2174, train loss = nan, time = 12.024
# Epoch 0/4, Iter 494/2174, train loss = nan, time = 14.276
# Epoch 0/4, Iter 495/2174, train loss = 57.504, time = 12.625
# Epoch 0/4, Iter 496/2174, train loss = 114.989, time = 12.660
# Epoch 0/4, Iter 497/2174, train loss = 36.300, time = 12.076
# Epoch 0/4, Iter 498/2174, train loss = 151.524, time = 13.010
# Epoch 0/4, Iter 499/2174, train loss = 131.441, time = 12.549
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 500/2174, train loss = nan, time = 13.107
# Epoch 0/4, Iter 501/2174, train loss = 44.271, time = 12.102
# Epoch 0/4, Iter 502/2174, train loss = nan, time = 12.428
# Epoch 0/4, Iter 503/2174, train loss = nan, time = 12.869
# Epoch 0/4, Iter 504/2174, train loss = 52.445, time = 12.947
# Epoch 0/4, Iter 505/2174, train loss = 209.044, time = 12.295
# Epoch 0/4, Iter 506/2174, train loss = 180.383, time = 12.077
# Epoch 0/4, Iter 507/2174, train loss = 23.829, time = 12.479
# Epoch 0/4, Iter 508/2174, train loss = nan, time = 12.708
# Epoch 0/4, Iter 509/2174, train loss = 186.316, time = 12.165
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 510/2174, train loss = nan, time = 13.208
# Epoch 0/4, Iter 511/2174, train loss = 27.672, time = 12.142
# Epoch 0/4, Iter 512/2174, train loss = 14.215, time = 12.676
# Epoch 0/4, Iter 513/2174, train loss = 69.686, time = 12.487
# Epoch 0/4, Iter 514/2174, train loss = 127.736, time = 12.441
# Epoch 0/4, Iter 515/2174, train loss = nan, time = 12.815
# Epoch 0/4, Iter 516/2174, train loss = 201.261, time = 12.132
# Epoch 0/4, Iter 517/2174, train loss = 95.281, time = 12.248
# Epoch 0/4, Iter 518/2174, train loss = 57.686, time = 12.887
# Epoch 0/4, Iter 519/2174, train loss = nan, time = 12.560
# Epoch 0/4, Iter 520/2174, train loss = 169.217, time = 13.256
# Epoch 0/4, Iter 521/2174, train loss = nan, time = 12.089
# Epoch 0/4, Iter 522/2174, train loss = nan, time = 12.397
# Epoch 0/4, Iter 523/2174, train loss = 142.294, time = 12.751
# Epoch 0/4, Iter 524/2174, train loss = 186.137, time = 12.150
# Epoch 0/4, Iter 525/2174, train loss = 53.483, time = 12.621
# Epoch 0/4, Iter 526/2174, train loss = nan, time = 12.216
# Epoch 0/4, Iter 527/2174, train loss = 147.211, time = 12.504
# Epoch 0/4, Iter 528/2174, train loss = 124.948, time = 12.300
# Epoch 0/4, Iter 529/2174, train loss = 144.471, time = 12.117
# Epoch 0/4, Iter 530/2174, train loss = 65.020, time = 13.349
# Epoch 0/4, Iter 531/2174, train loss = 94.020, time = 11.885
# Epoch 0/4, Iter 532/2174, train loss = 42.802, time = 12.292
# Epoch 0/4, Iter 533/2174, train loss = 23.860, time = 11.944
# Epoch 0/4, Iter 534/2174, train loss = nan, time = 12.653
# Epoch 0/4, Iter 535/2174, train loss = nan, time = 13.190
# Epoch 0/4, Iter 536/2174, train loss = nan, time = 12.138
# Epoch 0/4, Iter 537/2174, train loss = nan, time = 11.913
# Epoch 0/4, Iter 538/2174, train loss = 37.392, time = 11.966
# Epoch 0/4, Iter 539/2174, train loss = 137.546, time = 12.039
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 0/4, Iter 540/2174, train loss = nan, time = 12.582
# Epoch 0/4, Iter 541/2174, train loss = 135.115, time = 12.197
# Epoch 0/4, Iter 542/2174, train loss = 195.973, time = 12.311
# Epoch 0/4, Iter 543/2174, train loss = 143.889, time = 12.832
# Epoch 0/4, Iter 544/2174, train loss = nan, time = 14.896
# Epoch 0/4, Iter 545/2174, train loss = 76.947, time = 13.958
# Epoch 0/4, Iter 546/2174, train loss = 138.641, time = 12.101
# Epoch 0/4, Iter 547/2174, train loss = 67.118, time = 12.022
# Epoch 0/4, Iter 548/2174, train loss = 134.522, time = 12.685
# Epoch 0/4, Iter 549/2174, train loss = 90.678, time = 12.124
# Epoch 0/4, Iter 550/2174, train loss = 159.412, time = 13.315
# Epoch 0/4, Iter 551/2174, train loss = nan, time = 12.250
# Epoch 0/4, Iter 552/2174, train loss = 70.914, time = 12.783
# Epoch 0/4, Iter 553/2174, train loss = nan, time = 12.562
# Epoch 0/4, Iter 554/2174, train loss = 140.377, time = 12.445
# Epoch 0/4, Iter 555/2174, train loss = nan, time = 11.982
# Epoch 0/4, Iter 556/2174, train loss = nan, time = 12.640
# Epoch 0/4, Iter 557/2174, train loss = 40.794, time = 12.527
# Epoch 0/4, Iter 558/2174, train loss = 140.789, time = 12.600
# Epoch 0/4, Iter 559/2174, train loss = 147.437, time = 12.001
# Epoch 0/4, Iter 560/2174, train loss = 93.694, time = 13.088
# Epoch 0/4, Iter 561/2174, train loss = 105.844, time = 12.402
# Epoch 0/4, Iter 562/2174, train loss = nan, time = 12.344
# Epoch 0/4, Iter 563/2174, train loss = 38.563, time = 12.512
# Epoch 0/4, Iter 564/2174, train loss = 161.945, time = 12.257
# Epoch 0/4, Iter 565/2174, train loss = 44.074, time = 12.290
# Epoch 0/4, Iter 566/2174, train loss = nan, time = 12.816
# Epoch 0/4, Iter 567/2174, train loss = 54.366, time = 11.935
# Epoch 0/4, Iter 568/2174, train loss = nan, time = 12.423
# Epoch 0/4, Iter 569/2174, train loss = 73.124, time = 12.092
# Epoch 0/4, Iter 570/2174, train loss = 131.497, time = 14.276
# Epoch 0/4, Iter 571/2174, train loss = 59.300, time = 12.249
# Epoch 0/4, Iter 572/2174, train loss = 134.086, time = 12.383
# Epoch 0/4, Iter 573/2174, train loss = 97.546, time = 12.684
# Epoch 0/4, Iter 574/2174, train loss = nan, time = 11.931
# Epoch 0/4, Iter 575/2174, train loss = 81.958, time = 12.665
# Epoch 0/4, Iter 576/2174, train loss = nan, time = 12.876
# Epoch 0/4, Iter 577/2174, train loss = 117.256, time = 12.019
# Epoch 0/4, Iter 578/2174, train loss = nan, time = 12.065
# Epoch 0/4, Iter 579/2174, train loss = nan, time = 11.935
# Epoch 0/4, Iter 580/2174, train loss = 159.275, time = 13.189
# Epoch 0/4, Iter 581/2174, train loss = 144.865, time = 12.627
# Epoch 0/4, Iter 582/2174, train loss = nan, time = 11.837
# Epoch 0/4, Iter 583/2174, train loss = 93.470, time = 12.326
# Epoch 0/4, Iter 584/2174, train loss = nan, time = 11.939
# Epoch 0/4, Iter 585/2174, train loss = 61.797, time = 12.418
# Epoch 0/4, Iter 586/2174, train loss = 37.072, time = 12.414
# Epoch 0/4, Iter 587/2174, train loss = 69.638, time = 12.350
# Epoch 0/4, Iter 588/2174, train loss = 98.497, time = 11.888
# Epoch 0/4, Iter 589/2174, train loss = 25.406, time = 11.973
# Epoch 0/4, Iter 590/2174, train loss = 39.437, time = 12.960
# Epoch 0/4, Iter 591/2174, train loss = nan, time = 11.985
# Epoch 0/4, Iter 592/2174, train loss = 77.828, time = 12.175
# Epoch 0/4, Iter 593/2174, train loss = 54.606, time = 12.566
# Epoch 0/4, Iter 594/2174, train loss = 135.087, time = 12.734
# Epoch 0/4, Iter 595/2174, train loss = 87.743, time = 11.880
# Epoch 0/4, Iter 596/2174, train loss = 182.891, time = 12.048
# Epoch 0/4, Iter 597/2174, train loss = 174.171, time = 16.010
# Epoch 0/4, Iter 598/2174, train loss = 135.579, time = 12.755
# Epoch 0/4, Iter 599/2174, train loss = 114.639, time = 12.366
# Epoch 0/4, Iter 600/2174, train loss = 38.763, time = 13.187
# Epoch 0/4, Iter 601/2174, train loss = 129.601, time = 11.969
# Epoch 0/4, Iter 602/2174, train loss = 111.141, time = 12.239
# Epoch 0/4, Iter 603/2174, train loss = nan, time = 12.741
# Epoch 0/4, Iter 604/2174, train loss = 135.469, time = 12.505
# Epoch 0/4, Iter 605/2174, train loss = nan, time = 12.031
# Epoch 0/4, Iter 606/2174, train loss = nan, time = 12.158
# Epoch 0/4, Iter 607/2174, train loss = 41.027, time = 15.195
# Epoch 0/4, Iter 608/2174, train loss = 87.594, time = 12.278
# Epoch 0/4, Iter 609/2174, train loss = 33.397, time = 12.443
# Epoch 0/4, Iter 610/2174, train loss = 44.697, time = 12.519
# Epoch 0/4, Iter 611/2174, train loss = 131.631, time = 11.856
# Epoch 0/4, Iter 612/2174, train loss = nan, time = 15.519
# Epoch 0/4, Iter 613/2174, train loss = 104.367, time = 12.366
# Epoch 0/4, Iter 614/2174, train loss = 114.613, time = 11.944
# Epoch 0/4, Iter 615/2174, train loss = 29.676, time = 12.228
# Epoch 0/4, Iter 616/2174, train loss = 66.042, time = 11.997
# Epoch 0/4, Iter 617/2174, train loss = 137.363, time = 12.828
# Epoch 0/4, Iter 618/2174, train loss = 87.579, time = 12.010
# Epoch 0/4, Iter 619/2174, train loss = 88.619, time = 12.004
# Epoch 0/4, Iter 620/2174, train loss = 36.948, time = 12.441
# Epoch 0/4, Iter 621/2174, train loss = 40.241, time = 12.066
# Epoch 0/4, Iter 622/2174, train loss = 37.441, time = 12.497
# Epoch 0/4, Iter 623/2174, train loss = 92.029, time = 12.344
# Epoch 0/4, Iter 624/2174, train loss = 75.934, time = 12.409
# Epoch 0/4, Iter 625/2174, train loss = 87.700, time = 12.152
# Epoch 0/4, Iter 626/2174, train loss = 49.828, time = 11.938
# Epoch 0/4, Iter 627/2174, train loss = 184.469, time = 12.454
# Epoch 0/4, Iter 628/2174, train loss = 38.083, time = 12.162
# Epoch 0/4, Iter 629/2174, train loss = 77.089, time = 11.677
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# ...
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 3/4, Iter 1978/2174, train loss = nan, time = 13.115
# Epoch 3/4, Iter 1979/2174, train loss = nan, time = 11.936
# Epoch 3/4, Iter 1980/2174, train loss = nan, time = 11.722
# Epoch 3/4, Iter 1981/2174, train loss = 84.742, time = 11.925
# Epoch 3/4, Iter 1982/2174, train loss = 48.039, time = 11.825
# Epoch 3/4, Iter 1983/2174, train loss = nan, time = 12.743
# Epoch 3/4, Iter 1984/2174, train loss = nan, time = 11.889
# Epoch 3/4, Iter 1985/2174, train loss = 16.552, time = 11.825
# Epoch 3/4, Iter 1986/2174, train loss = 29.522, time = 15.930
# Epoch 3/4, Iter 1987/2174, train loss = nan, time = 12.130
# Epoch 3/4, Iter 1988/2174, train loss = 17.019, time = 14.078
# Epoch 3/4, Iter 1989/2174, train loss = nan, time = 11.880
# Epoch 3/4, Iter 1990/2174, train loss = 23.008, time = 15.867
# Epoch 3/4, Iter 1991/2174, train loss = 35.329, time = 12.216
# Epoch 3/4, Iter 1992/2174, train loss = 29.046, time = 11.962
# Epoch 3/4, Iter 1993/2174, train loss = 10.781, time = 13.140
# Epoch 3/4, Iter 1994/2174, train loss = 19.941, time = 11.935
# Epoch 3/4, Iter 1995/2174, train loss = nan, time = 11.641
# Epoch 3/4, Iter 1996/2174, train loss = 12.787, time = 12.331
# Epoch 3/4, Iter 1997/2174, train loss = 50.185, time = 12.459
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 3/4, Iter 1998/2174, train loss = nan, time = 13.768
# Epoch 3/4, Iter 1999/2174, train loss = 28.644, time = 12.396
# Epoch 3/4, Iter 2000/2174, train loss = 25.565, time = 11.801
# Epoch 3/4, Iter 2001/2174, train loss = 33.966, time = 12.337
# Epoch 3/4, Iter 2002/2174, train loss = 26.110, time = 12.302
# Epoch 3/4, Iter 2003/2174, train loss = 21.086, time = 11.948
# Epoch 3/4, Iter 2004/2174, train loss = nan, time = 12.071
# Epoch 3/4, Iter 2005/2174, train loss = 28.201, time = 12.437
# Epoch 3/4, Iter 2006/2174, train loss = nan, time = 12.389
# Epoch 3/4, Iter 2007/2174, train loss = 53.738, time = 12.302
# Epoch 3/4, Iter 2008/2174, train loss = 24.791, time = 12.884
# Epoch 3/4, Iter 2009/2174, train loss = nan, time = 12.593
# Epoch 3/4, Iter 2010/2174, train loss = 19.612, time = 11.846
# Epoch 3/4, Iter 2011/2174, train loss = 18.450, time = 12.456
# Epoch 3/4, Iter 2012/2174, train loss = 37.899, time = 12.385
# Epoch 3/4, Iter 2013/2174, train loss = 22.164, time = 11.894
# Epoch 3/4, Iter 2014/2174, train loss = nan, time = 12.683
# Epoch 3/4, Iter 2015/2174, train loss = 23.783, time = 12.190
# Epoch 3/4, Iter 2016/2174, train loss = nan, time = 12.354
# Epoch 3/4, Iter 2017/2174, train loss = 80.786, time = 12.150
# Epoch 3/4, Iter 2018/2174, train loss = 57.998, time = 13.146
# Epoch 3/4, Iter 2019/2174, train loss = 106.976, time = 12.159
# Epoch 3/4, Iter 2020/2174, train loss = 23.365, time = 11.798
# Epoch 3/4, Iter 2021/2174, train loss = 288.760, time = 12.134
# Epoch 3/4, Iter 2022/2174, train loss = 34.695, time = 12.305
# Epoch 3/4, Iter 2023/2174, train loss = 26.278, time = 11.957
# Epoch 3/4, Iter 2024/2174, train loss = 36.795, time = 13.030
# Epoch 3/4, Iter 2025/2174, train loss = nan, time = 11.893
# Epoch 3/4, Iter 2026/2174, train loss = nan, time = 11.834
# Epoch 3/4, Iter 2027/2174, train loss = 87.343, time = 12.429
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 3/4, Iter 2028/2174, train loss = nan, time = 12.771
# Epoch 3/4, Iter 2029/2174, train loss = 10.008, time = 12.176
# Epoch 3/4, Iter 2030/2174, train loss = nan, time = 12.770
# Epoch 3/4, Iter 2031/2174, train loss = 21.625, time = 11.989
# Epoch 3/4, Iter 2032/2174, train loss = nan, time = 11.761
# Epoch 3/4, Iter 2033/2174, train loss = 19.898, time = 12.203
# Epoch 3/4, Iter 2034/2174, train loss = nan, time = 12.495
# Epoch 3/4, Iter 2035/2174, train loss = nan, time = 12.679
# Epoch 3/4, Iter 2036/2174, train loss = 17.155, time = 11.999
# Epoch 3/4, Iter 2037/2174, train loss = 20.726, time = 11.948
# Epoch 3/4, Iter 2038/2174, train loss = 27.795, time = 13.047
# Epoch 3/4, Iter 2039/2174, train loss = nan, time = 11.797
# Epoch 3/4, Iter 2040/2174, train loss = 20.505, time = 12.098
# Epoch 3/4, Iter 2041/2174, train loss = 32.463, time = 11.737
# Epoch 3/4, Iter 2042/2174, train loss = 45.049, time = 11.782
# Epoch 3/4, Iter 2043/2174, train loss = 51.764, time = 12.685
# Epoch 3/4, Iter 2044/2174, train loss = 37.239, time = 11.797
# Epoch 3/4, Iter 2045/2174, train loss = 56.501, time = 12.403
# Epoch 3/4, Iter 2046/2174, train loss = nan, time = 11.907
# Epoch 3/4, Iter 2047/2174, train loss = 77.158, time = 11.896
# Epoch 3/4, Iter 2048/2174, train loss = 32.052, time = 12.953
# Epoch 3/4, Iter 2049/2174, train loss = 20.185, time = 12.152
# Epoch 3/4, Iter 2050/2174, train loss = 40.918, time = 12.250
# Epoch 3/4, Iter 2051/2174, train loss = 161.458, time = 12.301
# Epoch 3/4, Iter 2052/2174, train loss = 106.532, time = 13.859
# Epoch 3/4, Iter 2053/2174, train loss = 112.560, time = 12.491
# Epoch 3/4, Iter 2054/2174, train loss = 78.876, time = 11.794
# Epoch 3/4, Iter 2055/2174, train loss = 62.155, time = 12.615
# Epoch 3/4, Iter 2056/2174, train loss = 25.924, time = 12.471
# Epoch 3/4, Iter 2057/2174, train loss = nan, time = 14.936
# Epoch 3/4, Iter 2058/2174, train loss = 23.816, time = 13.383
# Epoch 3/4, Iter 2059/2174, train loss = 8.722, time = 11.671
# Epoch 3/4, Iter 2060/2174, train loss = 49.334, time = 11.668
# Epoch 3/4, Iter 2061/2174, train loss = 35.428, time = 12.468
# Epoch 3/4, Iter 2062/2174, train loss = 51.964, time = 12.338
# Epoch 3/4, Iter 2063/2174, train loss = 33.303, time = 11.598
# Epoch 3/4, Iter 2064/2174, train loss = nan, time = 12.060
# Epoch 3/4, Iter 2065/2174, train loss = 33.568, time = 12.330
# Epoch 3/4, Iter 2066/2174, train loss = nan, time = 11.732
# Epoch 3/4, Iter 2067/2174, train loss = nan, time = 11.610
# Epoch 3/4, Iter 2068/2174, train loss = 21.831, time = 12.332
# Epoch 3/4, Iter 2069/2174, train loss = nan, time = 11.799
# Epoch 3/4, Iter 2070/2174, train loss = 26.481, time = 11.568
# Epoch 3/4, Iter 2071/2174, train loss = nan, time = 15.217
# Epoch 3/4, Iter 2072/2174, train loss = 67.478, time = 11.910
# Epoch 3/4, Iter 2073/2174, train loss = 43.280, time = 14.160
# Epoch 3/4, Iter 2074/2174, train loss = 8.539, time = 11.628
# Epoch 3/4, Iter 2075/2174, train loss = 40.788, time = 12.275
# Epoch 3/4, Iter 2076/2174, train loss = 14.958, time = 14.289
# Epoch 3/4, Iter 2077/2174, train loss = 44.426, time = 12.260
# Epoch 3/4, Iter 2078/2174, train loss = 116.563, time = 13.077
# Epoch 3/4, Iter 2079/2174, train loss = 16.357, time = 11.676
# Epoch 3/4, Iter 2080/2174, train loss = 26.757, time = 15.890
# Epoch 3/4, Iter 2081/2174, train loss = nan, time = 12.203
# Epoch 3/4, Iter 2082/2174, train loss = 22.999, time = 12.197
# Epoch 3/4, Iter 2083/2174, train loss = 65.026, time = 12.426
# Epoch 3/4, Iter 2084/2174, train loss = 46.407, time = 11.857
# Epoch 3/4, Iter 2085/2174, train loss = 113.898, time = 11.696
# Epoch 3/4, Iter 2086/2174, train loss = 71.839, time = 12.288
# Epoch 3/4, Iter 2087/2174, train loss = 12.721, time = 11.823
# Epoch 3/4, Iter 2088/2174, train loss = 41.046, time = 13.185
# Epoch 3/4, Iter 2089/2174, train loss = nan, time = 11.759
# Epoch 3/4, Iter 2090/2174, train loss = 20.082, time = 12.588
# Epoch 3/4, Iter 2091/2174, train loss = nan, time = 12.350
# Epoch 3/4, Iter 2092/2174, train loss = nan, time = 12.125
# Epoch 3/4, Iter 2093/2174, train loss = 58.672, time = 16.380
# Epoch 3/4, Iter 2094/2174, train loss = 13.235, time = 11.783
# Epoch 3/4, Iter 2095/2174, train loss = 59.303, time = 11.761
# Epoch 3/4, Iter 2096/2174, train loss = nan, time = 11.462
# Epoch 3/4, Iter 2097/2174, train loss = nan, time = 12.636
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 3/4, Iter 2098/2174, train loss = nan, time = 13.135
# Epoch 3/4, Iter 2099/2174, train loss = 85.400, time = 11.806
# Epoch 3/4, Iter 2100/2174, train loss = 68.591, time = 11.895
# Epoch 3/4, Iter 2101/2174, train loss = 20.670, time = 11.977
# Epoch 3/4, Iter 2102/2174, train loss = 21.768, time = 12.486
# Epoch 3/4, Iter 2103/2174, train loss = nan, time = 12.055
# Epoch 3/4, Iter 2104/2174, train loss = nan, time = 11.699
# Epoch 3/4, Iter 2105/2174, train loss = 119.214, time = 11.686
# Epoch 3/4, Iter 2106/2174, train loss = 13.580, time = 12.156
# Epoch 3/4, Iter 2107/2174, train loss = 15.117, time = 11.897
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 3/4, Iter 2108/2174, train loss = nan, time = 12.882
# Epoch 3/4, Iter 2109/2174, train loss = 73.334, time = 11.605
# Epoch 3/4, Iter 2110/2174, train loss = 13.866, time = 12.246
# Epoch 3/4, Iter 2111/2174, train loss = 21.894, time = 12.043
# Epoch 3/4, Iter 2112/2174, train loss = 83.305, time = 11.915
# Epoch 3/4, Iter 2113/2174, train loss = 15.597, time = 12.533
# Epoch 3/4, Iter 2114/2174, train loss = 20.789, time = 11.991
# Epoch 3/4, Iter 2115/2174, train loss = nan, time = 12.394
# Epoch 3/4, Iter 2116/2174, train loss = 66.892, time = 12.441
# Epoch 3/4, Iter 2117/2174, train loss = 91.002, time = 12.349
# Epoch 3/4, Iter 2118/2174, train loss = 54.722, time = 13.073
# Epoch 3/4, Iter 2119/2174, train loss = 22.006, time = 11.824
# Epoch 3/4, Iter 2120/2174, train loss = nan, time = 11.976
# Epoch 3/4, Iter 2121/2174, train loss = 47.642, time = 11.880
# Epoch 3/4, Iter 2122/2174, train loss = 27.676, time = 12.115
# Epoch 3/4, Iter 2123/2174, train loss = 17.421, time = 12.924
# Epoch 3/4, Iter 2124/2174, train loss = 53.536, time = 12.303
# Epoch 3/4, Iter 2125/2174, train loss = 45.295, time = 11.730
# Epoch 3/4, Iter 2126/2174, train loss = 28.198, time = 12.099
# Epoch 3/4, Iter 2127/2174, train loss = nan, time = 12.469
# Epoch 3/4, Iter 2128/2174, train loss = 32.837, time = 12.549
# Epoch 3/4, Iter 2129/2174, train loss = 35.655, time = 11.832
# Epoch 3/4, Iter 2130/2174, train loss = 41.783, time = 11.739
# Epoch 3/4, Iter 2131/2174, train loss = nan, time = 11.513
# Epoch 3/4, Iter 2132/2174, train loss = 50.975, time = 12.471
# Epoch 3/4, Iter 2133/2174, train loss = nan, time = 12.406
# Epoch 3/4, Iter 2134/2174, train loss = nan, time = 12.370
# Epoch 3/4, Iter 2135/2174, train loss = nan, time = 11.627
# Epoch 3/4, Iter 2136/2174, train loss = nan, time = 11.757
# Epoch 3/4, Iter 2137/2174, train loss = 26.554, time = 11.948
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Epoch 3/4, Iter 2138/2174, train loss = nan, time = 12.453
# Epoch 3/4, Iter 2139/2174, train loss = 14.087, time = 12.501
# Epoch 3/4, Iter 2140/2174, train loss = 12.589, time = 12.338
# Epoch 3/4, Iter 2141/2174, train loss = 29.796, time = 12.466
# Epoch 3/4, Iter 2142/2174, train loss = 17.795, time = 12.531
# Epoch 3/4, Iter 2143/2174, train loss = 33.909, time = 12.229
# Epoch 3/4, Iter 2144/2174, train loss = nan, time = 12.381
# Epoch 3/4, Iter 2145/2174, train loss = 52.508, time = 14.908
# Epoch 3/4, Iter 2146/2174, train loss = 33.402, time = 12.185
# Epoch 3/4, Iter 2147/2174, train loss = 19.556, time = 12.142
# Epoch 3/4, Iter 2148/2174, train loss = 52.496, time = 12.448
# Epoch 3/4, Iter 2149/2174, train loss = 54.906, time = 12.214
# Epoch 3/4, Iter 2150/2174, train loss = nan, time = 12.537
# Epoch 3/4, Iter 2151/2174, train loss = 17.708, time = 11.660
# Epoch 3/4, Iter 2152/2174, train loss = nan, time = 12.357
# Epoch 3/4, Iter 2153/2174, train loss = 23.243, time = 12.309
# Epoch 3/4, Iter 2154/2174, train loss = 50.029, time = 12.396
# Epoch 3/4, Iter 2155/2174, train loss = nan, time = 12.676
# Epoch 3/4, Iter 2156/2174, train loss = 94.933, time = 11.627
# Epoch 3/4, Iter 2157/2174, train loss = 21.835, time = 12.250
# Epoch 3/4, Iter 2158/2174, train loss = 37.138, time = 13.098
# Epoch 3/4, Iter 2159/2174, train loss = 68.154, time = 11.676
# Epoch 3/4, Iter 2160/2174, train loss = 25.410, time = 11.875
# Epoch 3/4, Iter 2161/2174, train loss = nan, time = 12.577
# Epoch 3/4, Iter 2162/2174, train loss = 63.072, time = 11.814
# Epoch 3/4, Iter 2163/2174, train loss = 53.453, time = 12.197
# Epoch 3/4, Iter 2164/2174, train loss = 40.425, time = 11.749
# Epoch 3/4, Iter 2165/2174, train loss = nan, time = 15.652
# Epoch 3/4, Iter 2166/2174, train loss = nan, time = 11.535
# Epoch 3/4, Iter 2167/2174, train loss = 24.446, time = 11.467
# Epoch 3/4, Iter 2168/2174, train loss = 54.077, time = 11.888
# Epoch 3/4, Iter 2169/2174, train loss = 154.943, time = 11.261
# Epoch 3/4, Iter 2170/2174, train loss = nan, time = 14.430
# Epoch 3/4, Iter 2171/2174, train loss = 16.767, time = 11.663
# Epoch 3/4, Iter 2172/2174, train loss = 78.519, time = 11.341
# Epoch 3/4, Iter 2173/2174, train loss = nan, time = 11.362

# %% [markdown]
# ### Test Section

# %%
#Reset the model:
model = __models__['MSNet2D'](max_disp)

#Attempt loading the model from most recent checkpoint
state_dict = torch.load('trained_mobilenet/checkpoint_000003.ckpt')
model.load_state_dict(state_dict['model'])
# Out:
# <All keys matched successfully>

# %%
#Create testimgloader (will be same as testset for now)
data_dir = "/media/sf_shared/data"
split_name = "val"
#val_log_ids = "15c802a9-0f0e-3c87-b516-a3fa02f1ecb0"

val_log_ids = \
["00c561b9-2057-358d-82c6-5b06d76cebcf",
"033669d3-3d6b-3d3d-bd93-7985d86653ea",
"1d676737-4110-3f7e-bec0-0c90f74c248f",
"2d12da1d-5238-3870-bfbc-b281d5e8c1a1",
"33737504-3373-3373-3373-633738571776",
"39556000-3955-3955-3955-039557148672",
"5ab2697b-6e3e-3454-a36a-aba2c6f27818",
"64724064-6472-6472-6472-764725145600",
"6db21fda-80cd-3f85-b4a7-0aadeb14724d",
"70d2aea5-dbeb-333d-b21e-76a7f2f1ba1c",
"85bc130b-97ae-37fb-a129-4fc07c80cca7",
"cb0cba51-dfaf-34e9-a0c2-d931404c3dd8",
"cb762bb1-7ce1-3ba5-b53d-13c159b532c8",
"da734d26-8229-383f-b685-8086e58d1e05",
"e9a96218-365b-3ecd-a800-ed2c4c306c78",
"f1008c18-e76e-3c24-adcc-da9858fac145",
"f9fa3960-537f-3151-a1a3-37a9c0d6d7f7"]



argoverse_ds_test = ArgoverseDataset(data_dir, False, split_name, log_ids=val_log_ids)
print(len(argoverse_ds_test), 'total data logs within validation set')
#convert to data loader
TestImgLoader = DataLoader(argoverse_ds_test, 1, shuffle=False, num_workers = 4)
# Out:
# 1522 total data logs within validation set

# %%
def test(img_loader, test_iteration_limit = 100000):
    time_start = time.time()
    print("Generating the disparity maps...")
    timestamp = time.strftime("%m_%d_%Y_%H_%M_%S")
    folder_name = "results_"+timestamp
    results_path = os.path.join("./"+folder_name)
    pred_path = os.path.join(results_path, "predictions")
    truth_path = os.path.join(results_path, "ground_truth", "stereo_front_left_rect_disparity")
    truth_obj_path = os.path.join(results_path, "ground_truth", "stereo_front_left_rect_objects_disparity")
    ref_img_path = os.path.join(results_path, "reference_images")
    os.makedirs(results_path, exist_ok=True)
    os.makedirs(pred_path, exist_ok=True)
    os.makedirs(truth_path, exist_ok=True)
    os.makedirs(truth_obj_path, exist_ok=True)
    os.makedirs(ref_img_path, exist_ok=True)
    agg_time = 0
    for batch_idx, sample in enumerate(img_loader):
        
        if batch_idx % 5 == 0:
            clear_output(wait=True)
        print('Batch ', batch_idx, 'out of ', len(img_loader))
        
        disp_est_tn, inf_time = test_sample(sample)
        agg_time = agg_time + inf_time
        print('Inference time: ', inf_time, 'running average: ', agg_time/(batch_idx+1), 'total run-time: ', time.time() - time_start)
        disp_est_np = tensor2numpy(disp_est_tn)
        #These should be zero...
        top_pad_np = tensor2numpy(sample["top_pad"])
        right_pad_np = tensor2numpy(sample["right_pad"])
        disp_truth_np = tensor2numpy(sample["disparity"])
        left_truth_np = tensor2numpy(sample["left_truth_img"])
        disp_truth_obj_np = tensor2numpy(sample["disparity_obj"])

        left_filenames = sample["left_filename"]

        
        for disp_est, disp_truth, disp_truth_obj, top_pad, right_pad, fn, left_img in zip(disp_est_np, disp_truth_np, disp_truth_obj_np, top_pad_np, right_pad_np, left_filenames, left_truth_np):
            #print('[result] disp_est shape, ', disp_est.shape, 'disp_truth_size', disp_truth.shape, 'left_img shape', left_img.shape)

            assert len(disp_est.shape) == 2                        
            disp_est[disp_est < 0] = 0
            #continue to convert??
            disp_est = np.uint16(disp_est*256)#the otehr version has a *256
            disp_truth = np.uint16(disp_truth*256)
            disp_truth_obj = np.uint16(disp_truth*256)

            truth_img = np.uint8(left_img.transpose((1,2,0))*255)
            name = fn.split('/')
            name = name[-1].split('.')
            pred_name = 'pred'+name[0]+'.png'
            truth_name = 'truth'+name[0]+'.png'
            truth_obj_name = 'truth_obj'+name[0]+'.png'
            img_name = 'img'+name[0]+'.png'

            pred_fn = os.path.join(pred_path, pred_name)
            truth_fn = os.path.join(truth_path, truth_name)
            truth_obj_fn = os.path.join(truth_obj_path, truth_obj_name)
            img_fn = os.path.join(ref_img_path, img_name)

            cv2.imwrite(pred_fn, disp_est)
            cv2.imwrite(truth_fn, disp_truth)
            cv2.imwrite(truth_obj_fn, disp_truth_obj)
            cv2.imwrite(img_fn, truth_img)
            


        if batch_idx >= test_iteration_limit:
            break
    
    print('Total time: ', time.time() - time_start )
    return results_path, pred_path, truth_path, truth_obj_path, ref_img_path

# %%
@make_nograd_func
def test_sample(sample):

    model.eval()
    if len(sample['left'].shape) == 3:
        #reshape:
        c, h, w = sample['left'].shape
        left_img = torch.reshape(sample['left'], (1, c,h,w))
        right_img = torch.reshape(sample['right'], (1, c,h,w))
    else:
        left_img = sample['left']
        right_img = sample['right']
    istart = time.time()
    disp_ests = model(left_img, right_img)
    inf_time = time.time() - istart
    return disp_ests[-1], inf_time

# %%
@make_nograd_func
def test_single_instance(index, dataset,default_size = (512, 960), bFlip_to_depth = False, focal_length=0, baseline=.2986):
    #Grab thing:
    sample = dataset.__getitem__(index)
    disp_est = test_sample(sample)
    
    disp_est_np = np.reshape(tensor2numpy(disp_est), default_size)
    disp_est_np = np.float32(disp_est_np)
    disp_est_np[disp_est_np < 0] = 0
    
    if bFlip_to_depth:
        valid_pixels = disp_est_np > 0    
        disp_est_np = np.float32((focal_length * baseline)/(disp_est_np + (1.0-valid_pixels)))

    #Dilate map:
    map_dil = cv2.dilate(disp_est_np, kernel=np.ones((2,2), np.uint8), iterations=7)
    li = sample["left_truth_img"].permute(1,2,0).numpy()
    map_true = sample["disparity"]
    map_dil_true = cv2.dilate(map_true, kernel=np.ones((2,2), np.uint8), iterations=7)

    plt.figure(figsize=(24, 18), dpi=150)
    plt.subplot(1,3,1)
    plt.imshow(li)
    plt.subplot(1,3,2)
    plt.imshow(map_dil)
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.subplot(1,3,3)
    plt.imshow(map_dil_true)
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.show()

    return disp_est_np, map_true

# %%
#Get focal length information in case we need it:
'''
STEREO_FRONT_LEFT_RECT = RECTIFIED_STEREO_CAMERA_LIST[0]
STEREO_FRONT_RIGHT_RECT = RECTIFIED_STEREO_CAMERA_LIST[1]
BASELINE = 0.2986 

calib_data = argoverse_ds_test.stereo_data_loader.get_log_calibration_data(log_id=test_log_id)
camera_config = get_calibration_config(calib_data, camera_name=STEREO_FRONT_LEFT_RECT)
focal_length = camera_config.intrinsic[0,0]
'''
# Out:
# '\nSTEREO_FRONT_LEFT_RECT = RECTIFIED_STEREO_CAMERA_LIST[0]\nSTEREO_FRONT_RIGHT_RECT = RECTIFIED_STEREO_CAMERA_LIST[1]\nBASELINE = 0.2986 \n\ncalib_data = argoverse_ds_test.stereo_data_loader.get_log_calibration_data(log_id=test_log_id)\ncamera_config = get_calibration_config(calib_data, camera_name=STEREO_FRONT_LEFT_RECT)\nfocal_length = camera_config.intrinsic[0,0]\n'

# %%
#Can test a single instance this way
#reset the model:
#Reset the model:
model = __models__['MSNet2D'](max_disp)

#Attempt loading the model from most recent checkpoint
state_dict = torch.load('trained_mobilenet/checkpoint_000000.ckpt')
model.load_state_dict(state_dict['model'])

pred, truth = test_single_instance(10, argoverse_ds_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb Cell 17 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a> state_dict = torch.load('trained_mobilenet/checkpoint_000000.ckpt')
#       <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a> model.load_state_dict(state_dict['model'])
# ---> <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a> pred, truth = test_single_instance(10, argoverse_ds_test)
#
# File ~/Desktop/249_project/testing_build/mobilestereonet/utils/experiment.py:27, in make_nograd_func.<locals>.wrapper(*f_args, **f_kwargs)
#      25 def wrapper(*f_args, **f_kwargs):
#      26     with torch.no_grad():
# ---> 27         ret = func(*f_args, **f_kwargs)
#      28     return ret
#
# /home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb Cell 17 in test_single_instance(index, dataset, default_size, bFlip_to_depth, focal_length, baseline)
#       <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> sample = dataset.__getitem__(index)
#       <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> disp_est = test_sample(sample)
# ----> <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> print(disp_est.shape)
#       <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a> disp_est_np = np.reshape(tensor2numpy(disp_est), default_size)
#       <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a> disp_est_np = np.float32(disp_est_np)
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %% [markdown]
# ## Now evaluate!

# %%
results_path, pred_path, truth_path, truth_obj_path, ref_img_path = test(TestImgLoader)
# Out:
# Batch  1520 out of  1522
# Inference time:  11.228880643844604 running average:  11.387183494586681 total run-time:  17407.141325235367
# Batch  1521 out of  1522
# Inference time:  10.41815185546875 running average:  11.386546811512359 total run-time:  17417.61379957199
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> results_path, pred_path, truth_path, truth_obj_path, ref_img_path = test(TestImgLoader)
#
# /home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb Cell 19 in test(img_loader, test_iteration_limit)
#      <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X24sZmlsZQ%3D%3D?line=66'>67</a>     if batch_idx >= test_iteration_limit:
#      <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X24sZmlsZQ%3D%3D?line=67'>68</a>         break
# ---> <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X24sZmlsZQ%3D%3D?line=69'>70</a> print('Total time: ', time.time() - start_time )
#      <a href='vscode-notebook-cell:/home/ubutubiggerbetter/Desktop/249_project/testing_build/CMPE249_Project/mobile_net_train_and_test.ipynb#X24sZmlsZQ%3D%3D?line=70'>71</a> return results_path, pred_path, truth_path, truth_obj_path, ref_img_path
#
# NameError: name 'start_time' is not defined

# %%
#Create save dir for disparity error images:
disp_err_path = os.path.join(results_path, 'disparity_err_img')
os.makedirs(disp_err_path, exist_ok=True)
#Convert to aboslute paths:
pred_path = Path(os.path.abspath(pred_path))
outer_truth_path = Path(os.path.abspath(os.path.join(truth_path, '..')))
disp_err_path = Path(os.path.abspath(disp_err_path))


#Create stereo evaluator:
evaluator = StereoEvaluator(
    pred_path, 
    outer_truth_path, 
    disp_err_path,
    save_disparity_error_image=True,
    num_procs=-1
)
#Evaluate:
metrics = evaluator.evaluate() 

print(metrics[0])
# Out:
# {'all:10': 86.65439287549238, 'fg:10': 86.65520206362855, 'bg:10': 86.45833333333334, 'all*:10': 86.65439287549238, 'fg*:10': 86.65520206362855, 'bg*:10': 86.45833333333334, 'all:5': 97.15276588456928, 'fg:5': 97.15821152192605, 'bg:5': 95.83333333333334, 'all*:5': 97.15276588456928, 'fg*:5': 97.15821152192605, 'bg*:5': 95.83333333333334, 'all:3': 97.15276588456928, 'fg:3': 97.15821152192605, 'bg:3': 95.83333333333334, 'all*:3': 97.15276588456928, 'fg*:3': 97.15821152192605, 'bg*:3': 95.83333333333334}

# %%
#The following only works if you have a GPU setup. I do not-but it does something simlar to what's 
#already been impelmented

import torchvision
#Using argoverse's stereo loader thing:
data_dir = Path("/media/sf_shared/data")
output_dir = os.path.join(os.path.abspath('./'), 'evaluation')
os.makedirs(output_dir, exist_ok=True)

#Define the transforms you want:
transforms = torchvision.transforms.Compose(
    [
        torchvision.transforms.Resize(size=(512, 960)),
        torchvision.transforms.Normalize(
            mean=(0.485, 0.456, 0.406),  # ResNet mean image normalization
            std=(0.229, 0.224, 0.225),  # ResNet std image normalization
        ),
    ]
)
from argoverse.evaluation.stereo.generate_stereo_results import generate_stereo_results

#Fails because of no cude device
generate_stereo_results(model, data_dir, output_dir, transforms)
metrics = evaluator.evaluate()
print(f"{json.dumps(metrics, sort_keys=False, indent=4)}")
